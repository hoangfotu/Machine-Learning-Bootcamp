# %% [markdown]
# <img align="center" src="https://iili.io/3wI8gI.png" style="height:90px" style="width:30px"/>

# %% [markdown]
# # Data Analytics - Basics

# %% [markdown]
# ## Lab 1: World happiness report
# Import pandas and read the `world-happiness-report.csv` file. Display the 5 first rows

# %% [markdown]
# <img src = 'https://wabstalk.com/wp-content/uploads/2019/09/happiness.jpeg'>

# %%
# import libraries
# read data 'world-happiness-report.csv'
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %% [markdown]
# ### Q1
# Check for all elements in the column `Regional indicator` whether they are equal to "Western Europe". Save the boolean Series to a variable named `mask`.

# %%
# code here

# %% [markdown]
# ### Q2
# How many values are set to `False` in our `mask` Series?

# %%
# code here
# Out:
# False    128
# True      21
# Name: Regional indicator, dtype: int64

# %% [markdown]
# ### Q3
# Use the mask variable to filter your dataframe so it returns countries from Western Europe

# %%
# code here
# Out:
#       Country name Regional indicator  Ladder score  \
# 0          Finland     Western Europe         7.842
# 1          Denmark     Western Europe         7.620
# 2      Switzerland     Western Europe         7.571
# 3          Iceland     Western Europe         7.554
# 4      Netherlands     Western Europe         7.464
# 5           Norway     Western Europe         7.392
# 6           Sweden     Western Europe         7.363
# 7       Luxembourg     Western Europe         7.324
# 9          Austria     Western Europe         7.268
# 12         Germany     Western Europe         7.155
# 14         Ireland     Western Europe         7.085
# 16  United Kingdom     Western Europe         7.064
# 19         Belgium     Western Europe         6.834
# 20          France     Western Europe         6.690
# 22           Malta     Western Europe         6.602
# 26           Spain     Western Europe         6.491
# 27           Italy     Western Europe         6.483
# ...

# %% [markdown]
# ### Q4
# Filter the df on origin, `Healthy life expectancy` and `Logged GDP per capita`.
#
#     - Regional indicator should be East Asia
#     - Healthy life expectancy should be higher than 70
#     - Logged GDP per capita should be above 8
#
# *Your filtered df should return 3 countries*

# %%
# code here
# Out:
# (3, 20)

# %% [markdown]
# ### Q5
# Filter the DataFrame for all countries located in 'Latin America and Caribbean' with Social support between 0.75 and 0.85

# %%
# code here
# Out:
#    Country name           Regional indicator  Ladder score  \
# 29    Guatemala  Latin America and Caribbean         6.435
# 35       Mexico  Latin America and Caribbean         6.317
# 48  El Salvador  Latin America and Caribbean         6.061
# 51     Colombia  Latin America and Caribbean         6.012
# 58     Honduras  Latin America and Caribbean         5.919
# 62         Peru  Latin America and Caribbean         5.840
# 65      Ecuador  Latin America and Caribbean         5.764
# 68      Bolivia  Latin America and Caribbean         5.716
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 29                           0.073         6.577         6.292
# 35                           0.053         6.420         6.213
# 48                           0.065         6.188         5.933
# 51                           0.061         6.132         5.892
# 58                           0.082         6.081         5.758
# ...

# %% [markdown]
# ### Q6
# Filter the df so based on the following criterias
# - only country present in `name_lst` are shown
# - only if they have the upperwhisker is higher than 7 or the Healthy life expectancy is lower than 65

# %%
name_lst = ['Australia', 'Mauritius', 'Tanzania', 'El Salvador', 'Bahrain', 'Israel']

# %%
# code here
# Out:
#     Country name            Regional indicator  Ladder score  \
# 10     Australia         North America and ANZ         7.183
# 11        Israel  Middle East and North Africa         7.157
# 141     Tanzania            Sub-Saharan Africa         3.623
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 10                            0.041         7.265         7.102
# 11                            0.034         7.224         7.090
# 141                           0.071         3.762         3.485
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 10                  10.796           0.940                   73.900
# 11                  10.575           0.939                   73.503
# 141                  7.876           0.702                   57.999
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 10                          0.914       0.159                      0.442
# ...

# %% [markdown]
# ### Bonus Challenges
# #### Q1
# Filter the df so only countries with a ratio between 'lowerwhisker' and 'Supperwhisker' higher than 0.96 are shown

# %%
# code here
# Out:
#      Country name                  Regional indicator  Ladder score  \
# 0         Finland                      Western Europe         7.842
# 1         Denmark                      Western Europe         7.620
# 2     Switzerland                      Western Europe         7.571
# 3         Iceland                      Western Europe         7.554
# 4     Netherlands                      Western Europe         7.464
# ..            ...                                 ...           ...
# 96   Turkmenistan  Commonwealth of Independent States         5.066
# 99           Laos                      Southeast Asia         5.030
# 100    Bangladesh                          South Asia         5.025
# 103        Turkey        Middle East and North Africa         4.948
# 138         India                          South Asia         3.819
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# ...

# %% [markdown]
# #### Q2
#
# Filter the dataframe so only countires with NaN-values in the Generosity column are shown

# %%
# code here
# Out:
#             Country name                  Regional indicator  Ladder score  \
# 19               Belgium                      Western Europe         6.834
# 27                 Italy                      Western Europe         6.483
# 82   Congo (Brazzaville)                  Sub-Saharan Africa         5.342
# 89            Azerbaijan  Commonwealth of Independent States         5.171
# 90              Cameroon                  Sub-Saharan Africa         5.142
# 98                 Benin                  Sub-Saharan Africa         5.045
# 100           Bangladesh                          South Asia         5.025
# 122              Lebanon        Middle East and North Africa         4.584
# 140                Yemen        Middle East and North Africa         3.658
# 148          Afghanistan                          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 19                            0.034         6.901         6.767
# ...

# %% [markdown]
# #### Q3
#
# Using the query-syntax, filter the df so it returns countries with Social support higher than 0.90
# that are not from the Western Europe

# %%
# code here
# Out:
#       Country name                  Regional indicator  Ladder score  \
# 8      New Zealand               North America and ANZ         7.277
# 10       Australia               North America and ANZ         7.183
# 11          Israel        Middle East and North Africa         7.157
# 13          Canada               North America and ANZ         7.103
# 17  Czech Republic          Central and Eastern Europe         6.965
# 18   United States               North America and ANZ         6.951
# 28        Slovenia          Central and Eastern Europe         6.461
# 30         Uruguay         Latin America and Caribbean         6.431
# 31       Singapore                      Southeast Asia         6.377
# 33        Slovakia          Central and Eastern Europe         6.331
# 37       Lithuania          Central and Eastern Europe         6.255
# 39         Estonia          Central and Eastern Europe         6.189
# 41      Uzbekistan  Commonwealth of Independent States         6.179
# ...

# %% [markdown]
# #### Q4
#
# Filter the df so only countries with "Europe" in their Regional indicator are shown.
#
# *Your df should return 38 rows*

# %%
# code here
# Out:
#               Country name          Regional indicator  Ladder score  \
# 0                  Finland              Western Europe         7.842
# 1                  Denmark              Western Europe         7.620
# 2              Switzerland              Western Europe         7.571
# 3                  Iceland              Western Europe         7.554
# 4              Netherlands              Western Europe         7.464
# 5                   Norway              Western Europe         7.392
# 6                   Sweden              Western Europe         7.363
# 7               Luxembourg              Western Europe         7.324
# 9                  Austria              Western Europe         7.268
# 12                 Germany              Western Europe         7.155
# 14                 Ireland              Western Europe         7.085
# 16          United Kingdom              Western Europe         7.064
# 17          Czech Republic  Central and Eastern Europe         6.965
# ...

# %% [markdown]
# ## Lab 2: Morty's orders in an Indian McDonald's
#
# Get what Morty wants in an Indian McDonald
# <img src= "https://legendary-digital-network-assets.s3.amazonaws.com/wp-content/uploads/2022/07/27070353/Rick-and-Morty-Season-6.jpg"  width="400" height="450">

# %%
# read the data 'India_Menu.csv'

# %% [markdown]
# ### Question 1: Fika (tea time)!!!
# It is tea time now. Morty wants to know in the `Menu Category` what choices does Morty have for the category `Desserts Menu` and `Beverages Menu`?

# %%
# code here
# Out:
# 19 rows
#       Menu Category                    Menu Items Per Serve Size  \
# 102   Desserts Menu         Small McFlurry - Oreo        86.79 g
# 103   Desserts Menu       Regular McFlurry - Oreo       147.38 g
# 115  Beverages Menu               Small Coca-Cola         299 ml
# 116  Beverages Menu              Medium Coca-Cola         394 ml
# 117  Beverages Menu               Large Coca-Cola         544 ml
# 118  Beverages Menu            Small Fanta Oragne         299 ml
# 119  Beverages Menu           Medium Fanta Orange         394 ml
# 120  Beverages Menu            Large Fanta Oragne         544 ml
# 121  Beverages Menu                Small Thums-up         299 ml
# 122  Beverages Menu               Medium Thums-up         394 ml
# 123  Beverages Menu                Large Thums-up         544 ml
# 124  Beverages Menu                  Small Sprite         299 ml
# 125  Beverages Menu                 Medium Sprite         394 ml
# ...

# %% [markdown]
# ### Question 2 : Morty wants a meal with the following conditions:
# - Cheese products
# - `Per Serve Size` is 195 g, 207 g or 240 g
# - `Sodium (mg)` <  1500 mg and > 1100

# %%
# code here
# Out:
#     Menu Category                      Menu Items Per Serve Size  \
# 104  Gourmet Menu  American Triple Cheese Chicken          195 g
# 105  Gourmet Menu      American Triple Cheese Veg          207 g
# 106  Gourmet Menu              Cheese Lava Burger          240 g
#
#      Energy (kCal)  Protein (g)  Total fat (g)  Sat Fat (g)  Trans fat (g)  \
# 104         457.94        24.43          22.65        11.56           0.17
# 105         524.69        19.54          23.16        14.78           0.19
# 106         671.06        14.99          33.48        14.12           0.21
#
#      Cholesterols (mg)  Total carbohydrate (g)  Total Sugars (g)  \
# 104              71.23                   37.45              7.64
# 105              48.74                   56.24              7.90
# 106              33.21                   74.25             16.27
#
#      Added Sugars (g)  Sodium (mg)
# 104              3.84      1396.17
# 105              3.84      1174.27
# ...

# %% [markdown]
# ### Question 3: Morty wants to eat a Wrap! What can he

# %%
# code here
# Out:
#    Menu Category          Menu Items Per Serve Size  Energy (kCal)  \
# 3   Regular Menu   Spicy Paneer Wrap          250 g         674.68
# 11  Regular Menu  Spicy Chicken Wrap          257 g         567.19
#
#     Protein (g)  Total fat (g)  Sat Fat (g)  Trans fat (g)  Cholesterols (mg)  \
# 3         20.96          39.10        19.73           0.26              40.93
# 11        23.74          26.89        12.54           0.27              87.63
#
#     Total carbohydrate (g)  Total Sugars (g)  Added Sugars (g)  Sodium (mg)
# 3                    59.27              3.50              1.08      1087.46
# 11                   57.06              2.52              1.08      1152.38

# %% [markdown]
# ### Question 4: Special diet
# Morty is working on his six pack. He want a burger with the following conditions
# - `Sat Fat (g)` < 15g
# - `Protein (g)` > 10g
# - `Cholesterols (mg)` < 40 mg
# - Not vegetarian
# __What choice does he have?__

# %%
# code here
# Out:
#     Menu Category            Menu Items Per Serve Size  Energy (kCal)  \
# 8    Regular Menu     Mc chicken Burger          173 g         400.80
# 9    Regular Menu  FILLET-O-FISH Burger          136 g         348.11
# 106  Gourmet Menu    Cheese Lava Burger          240 g         671.06
#
#      Protein (g)  Total fat (g)  Sat Fat (g)  Trans fat (g)  \
# 8          15.66          15.70         5.47           0.16
# 9          15.44          14.16         5.79           0.21
# 106        14.99          33.48        14.12           0.21
#
#      Cholesterols (mg)  Total carbohydrate (g)  Total Sugars (g)  \
# 8                31.17                   47.98              5.53
# 9                32.83                   38.85              5.58
# 106              33.21                   74.25             16.27
#
#      Added Sugars (g)  Sodium (mg)
# 8                4.49       766.33
# 9                3.54       530.54
# 106             10.01      1153.99

# %% [markdown]
# ### Question 5:  Morty wants the burger with the highest `Energy (kCal)`

# %%
# code here
# Out:
#     Menu Category                  Menu Items Per Serve Size  Energy (kCal)  \
# 107  Gourmet Menu  Chicken Cheese Lava Burger          307 g         834.36
#
#      Protein (g)  Total fat (g)  Sat Fat (g)  Trans fat (g)  \
# 107        27.37          45.18         17.0           0.27
#
#      Cholesterols (mg)  Total carbohydrate (g)  Total Sugars (g)  \
# 107              73.11                   76.03             16.75
#
#      Added Sugars (g)  Sodium (mg)
# 107             10.01      1745.04

# %% [markdown]
# ### Question 6: Trans fat is bad. Which meal has a ratio of Trans fat to total fat higher than 90%?
# Get all meals whose `Trans fat (g)`/`Total fat (g)` is higher than 0.9

# %%
# code here
# Out:
# 21  rows
#        Menu Category                   Menu Items Per Serve Size  \
# 25      Regular Menu       5 piece Chicken Strips          145 g
# 44    Breakfast Menu                     Espresso        26.5 ml
# 46    Breakfast Menu                Americano (S)       276.5 ml
# 47    Breakfast Menu                Americano (R)       347.5 ml
# 48    Breakfast Menu                Americano (L)         455 ml
# 67       McCafe Menu        English Breakfast (S)         279 ml
# 68       McCafe Menu        English Breakfast (R)         330 ml
# 69       McCafe Menu        English Breakfast (L)         456 ml
# 70       McCafe Menu  Moroccon Mint Green Tea (S)         279 ml
# 71       McCafe Menu  Moroccon Mint Green Tea (R)         330 ml
# 72       McCafe Menu  Moroccon Mint Green Tea (L)         456 ml
# 73       McCafe Menu     Strawberry Green Tea (S)         279 ml
# 74       McCafe Menu     Strawberry Green Tea (R)         330 ml
# ...

# %% [markdown]
# ### Question 7: What is the average grams for `Per Serve Size`
# note: do not include drinks

# %%
# code here
# Out:
# 116.15

# %% [markdown]
# ### Question 8: Morty wants to be a vegetarian this week. Find all burgers which is vegetarian

# %%
# code here
# Out:
#     Menu Category                     Menu Items Per Serve Size  \
# 0    Regular Menu               McVeggie™ Burger          168 g
# 4    Regular Menu            American Veg Burger          177 g
# 110  Gourmet Menu     McSpicy Premium Veg Burger        212.5 g
# 112  Gourmet Menu  Piri piri Mc Spicy Veg Burger          211 g
#
#      Energy (kCal)  Protein (g)  Total fat (g)  Sat Fat (g)  Trans fat (g)  \
# 0           402.05        10.24          13.83         5.34           0.16
# 4           512.17        15.30          23.45        10.51           0.17
# 110         634.71        22.44          39.21        20.46           0.20
# 112         517.98        11.97          24.53         6.01           0.18
#
#      Cholesterols (mg)  Total carbohydrate (g)  Total Sugars (g)  \
# 0                 2.49                   56.54              7.90
# 4                25.24                   56.96              7.85
# 110              43.68                   46.00              7.57
# ...
